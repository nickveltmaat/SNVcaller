# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel (r'Z:\Lymphoma research\SNV & Translocations in ctDNA from DLBCL (Nick)\1. SNVs in ctDNA\Data\PoN analysis\annotated_merged_PoN_decomposed_normalized.xlsx', 
                    sheet_name='Variant', skiprows=1)
df['Clinical Significance'] = df['Clinical Significance'].fillna('NaN')

# %%
df['Clinical Significance'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Clinical Significance'].str.contains("athog|espo")]#.iloc[:, 24:25]
# Out:
#      UID  Chrom   Position Ref Base Alt Base  Note Coding    Gene  \
# 202  203  chr11  108245021        A        -   NaN    Yes     ATM
# 208  209  chr12   49030395        G        -   NaN    Yes   KMT2D
# 231  232  chr12   49051150        G        -   NaN    Yes   KMT2D
# 234  235  chr12   49051717        G        -   NaN    Yes   KMT2D
# 235  236  chr12   49051743        G        -   NaN    Yes   KMT2D
# 247  248  chr16    3729210        G        -   NaN    Yes  CREBBP
# 257  258  chr16   10907448        -        C   NaN    Yes   CIITA
# 289  290  chr17    7676154        G        C   NaN    Yes    TP53
# 291  292  chr17   42218218        G        -   NaN    Yes  STAT5B
# 292  293  chr17   42218218        -        G   NaN    Yes  STAT5B
# 310  311   chrX  101360691        T        -   NaN    Yes     BTK
#
#              Transcript      Sequence Ontology  ... South Asian AF  \
# 202   ENST00000278616.8  frameshift_truncation  ...            NaN
# ...
